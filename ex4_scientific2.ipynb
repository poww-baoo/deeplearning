# %% [markdown]
# # ex4_scientific2
#
# ## Nội dung bài
#
# Hiển thị hai đồ thị $\sin(x)$ và $\cos(x)$ trong khoảng $x \in [-\pi, \pi]$.
#
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Sinh dữ liệu hàm số

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C = np.cos(X)
S = np.sin(X)

# %% [markdown]
# ### Kiểm tra dữ liệu

# %%
print(f'+ X: len={len(X)}, range=[{X.min():.2f}, {X.max():.2f}], 10 samples={X[:10]}')
print(f'+ cos(X): len={len(C)}, range=[{C.min():.2f}, {C.max():.2f}], 10 samples={C[:10]}')
print(f'+ sin(X): len={len(S)}, range=[{S.min():.2f}, {S.max():.2f}], 10 samples={S[:10]}')
# Out:
# + X: len=256, range=[-3.14, 3.14], 10 samples=[-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317]
# + cos(X): len=256, range=[-1.00, 1.00], 10 samples=[-1.         -0.99969645 -0.99878599 -0.99726917 -0.99514692 -0.99242051
#  -0.98909161 -0.98516223 -0.98063477 -0.97551197]
# + sin(X): len=256, range=[-1.00, 1.00], 10 samples=[-1.22464680e-16 -2.46374492e-02 -4.92599411e-02 -7.38525275e-02
#  -9.84002783e-02 -1.22888291e-01 -1.47301698e-01 -1.71625679e-01
#  -1.95845467e-01 -2.19946358e-01]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(X, C, color='blue', linewidth=2.5, label=r'$\cos(x)$')
ax.plot(X, S, color='red', linewidth=2.5, label=r'$\sin(x)$')

ax.set_xlim(X.min(), X.max())
ax.set_xticks(
    [-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
    [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$\pi/2$', r'$\pi$'],
)
ax.set_ylim(-1.1, 1.1)
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Đồ thị $\sin(x)$ và $\cos(x)$ trên $[-\pi, \pi]$')
ax.axhline(0, color='black', linewidth=0.8)
ax.axvline(0, color='black', linewidth=0.8)
ax.grid(alpha=0.25)
ax.legend()
plt.show()

# %% [markdown]
# # Kết thúc
